# %%
## 6 - June - 2023

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
with open('../Data/all_pitching_data_from_2018.html', encoding='utf-8') as file:
    page = file.read()
    
soup = BeautifulSoup(page, 'html.parser')
stats_table_code = soup.find(id='players_standard_pitching')

# %%
stats_DataFrame = pd.read_html(str(stats_table_code))[0]

# %%
stats_DataFrame[(stats_DataFrame['Name'] == 'Name') | (stats_DataFrame['Name'] == 'LgAvg per 180 IP')]
# Out:
#       Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP  \
# 25    Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 51    Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 77    Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 103   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 129   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 155   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 181   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 207   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 233   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 259   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 285   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 311   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 337   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 363   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 389   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 415   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 441   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 467   Rk              Name  Age   Tm   W   L  W-L%   ERA   G  GS  ...  WP
# 479  NaN  LgAvg per 180 IP  NaN  NaN  10  10  .500  4.05  89  20  ...   7
#
#       BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 25    BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 51    BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 77    BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 103   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 129   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 155   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 181   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 207   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 233   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 259   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 285   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 311   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 337   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 363   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 389   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 415   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 441   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 467   BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W
# 479  765   100  4.07  1.299  8.4  1.1  3.3  8.5  2.57
#
# [19 rows x 34 columns]

# %%
stats_DataFrame.shape
# Out:
# (480, 34)
